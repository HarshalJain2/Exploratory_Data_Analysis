# %% [markdown]
# ### About the dataset (Customer Tip Data)
#
# The dataset contains information about the 244 orders served at a restaurant in the United States. Each observation includes the factors related to the order like total bill, time, the total number of people in a group, gender of the person paying for the order and so on.
#
# Attribute Information:
#
# **total_bill:** Total bill (cost of the meal), including tax, in US dollars
#
# **tip:** Tip in US dollars
#
# **sex:** Sex of person paying for the meal
#
# **smoker:** There is a smoker in a group or not
#
# **day:** Day on which the order is served
#
# **time:** Time of the order
#
# **size:** Size of the group

# %% [markdown]
# **Import the required libraries**

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib as plt
from scipy.stats import variation

# %% [markdown]
# #### Load the customer tip dataset and print the first five observations

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_column',None)
df1=pd.read_csv('customer_tip.csv')
df1
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 4         24.59   3.61  Female     No   Sun  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 7         26.88   3.12    Male     No   Sun  Dinner     4
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 13        18.43   3.00    Male     No   Sun  Dinner     4
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# ...

# %%
df1.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Make a list of categorical and numerical variables in the data
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(df1.dtypes)
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
cat_vars = []
num_vars = []
for col in df1.columns:
    if df1[col].dtype == 'object' or df1[col].dtype.name == 'category':
        cat_vars.append(col)
    else:
        num_vars.append(col)
print('Categorical variables:', cat_vars)
print('Numerical variables:', num_vars)
# Out:
# Categorical variables: ['sex', 'smoker', 'day', 'time']
# Numerical variables: ['total_bill', 'tip', 'size']

# %%
cat_vars =df1.select_dtypes(include=['object','category']).columns
print('categorical variable:' ,cat_vars)
# Out:
# categorical variable: Index(['sex', 'smoker', 'day', 'time'], dtype='object')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Compute the average bill amount for each day
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df1['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df1.groupby(by='day')['total_bill'].mean()
# Out:
# day
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Thur    17.682742
# Name: total_bill, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Which gender is more generous in giving the tip?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print(df1.groupby(by='sex')['tip'].mean())
# Out:
# sex
# Female    2.833448
# Male      3.089618
# Name: tip, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. According to the data, were there more customers for dinner or lunch? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df1.groupby(by='time')['size'].count()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: size, dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Based on the statistical summary, comment on the variable 'tip'
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print(df1.groupby(by='sex')['tip'].mean())
print(df1.groupby(by='sex')['tip'].max())
print(df1.groupby(by='sex')['tip'].count())
print(df1.groupby(by='time')['tip'].mean())
print(df1.groupby(by='time')['tip'].max())
print(df1.groupby(by='time')['tip'].count())
# Out:
# sex
# Female    2.833448
# Male      3.089618
# Name: tip, dtype: float64
# sex
# Female     6.5
# Male      10.0
# Name: tip, dtype: float64
# sex
# Female     87
# Male      157
# Name: tip, dtype: int64
# time
# Dinner    3.102670
# Lunch     2.728088
# Name: tip, dtype: float64
# time
# Dinner    10.0
# Lunch      6.7
# Name: tip, dtype: float64
# time
# Dinner    176
# Lunch      68
# Name: tip, dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Find the busiest day in terms of the orders
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df1['day'].mode()
# Out:
# 0    Sat
# Name: day, dtype: object

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Is the variable 'total_bill' skewed? If yes, identify the type of skewness. Support your answer with a plot
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.kdeplot(data=df1,x='total_bill')
skewness=df1['total_bill'].skew()
print('Skewness coefficient:', skewness)
if skewness > 0:
    print('The distribution is right-skewed or positively skewed')
elif skewness < 0:
    print('The distribution is left-skewed or negatively skewed')
else:
    print('The distribution is symmetric')
# Out:
# Skewness coefficient: 1.1332130376158205
# The distribution is right-skewed or positively skewed

# %%
# Out:
# The distribution is right-skewed or positively skewed

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Is the tip amount dependent on the total bill?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
corr = df1['total_bill'].corr(df1['tip'])
print('Correlation coefficient between total_bill and tip:', corr)
if corr>0:
    print('tip amount dependent on the total bill')
else:
    print('tip amount not dependent on the total bill')
# Out:
# Correlation coefficient between total_bill and tip: 0.6757341092113641
# tip amount dependent on the total bill

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9.  What is the value under which 20% of the total bill would lie?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
twenty_percentile = df1['total_bill'].quantile(0.20)
print('The value under which 20% of the total bill would lie is:', twenty_percentile)
# Out:
# The value under which 20% of the total bill would lie is: 12.636

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Retrieve the orders where the bill amount is more than 2 standard deviation away from the average bill </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
avg_bill = df1['total_bill'].mean()
std_bill = df1['total_bill'].std()
cal_threshold = avg_bill + 2 * std_bill
outliers = df1[df1['total_bill'] > cal_threshold]
outliers
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 112       38.07   4.00    Male     No   Sun  Dinner     3
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 207       38.73   3.00    Male    Yes   Sat  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
